# %%
import utils

import numpy as np
from random import random, uniform, randint
from matplotlib import pyplot as plt
import pandas as pd

# %%
plt.figure(figsize=(7,7))
plt.plot(utils.generates_n_plates_wcco(wcco=utils.WCCoPrism(r=0.6, k=0.9), r=0.6, k=0.9, n=10000))
# Out:
# i had a problem with precision
# i had a problem with precision
# i had a problem with precision
# i had a problem with precision
# i had a problem with precision
# i had a problem with precision
